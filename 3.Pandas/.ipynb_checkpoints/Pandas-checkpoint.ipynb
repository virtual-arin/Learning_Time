# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(0, 30).reshape(5,6), index=['Row1', 'Row2', 'Row3', 'Row4', 'Row5'], columns=['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6'])
# Display the DataFrame
print(df)
# Out:
#       Column1  Column2  Column3  Column4  Column5  Column6
# Row1        0        1        2        3        4        5
# Row2        6        7        8        9       10       11
# Row3       12       13       14       15       16       17
# Row4       18       19       20       21       22       23
# Row5       24       25       26       27       28       29

# %%
df.to_csv('data.csv')

# %%
df.loc['Row3']
# Out:
# Column1    12
# Column2    13
# Column3    14
# Column4    15
# Column5    16
# Column6    17
# Name: Row3, dtype: int64

# %%
df.iloc[:,:]
# Out:
#       Column1  Column2  Column3  Column4  Column5  Column6
# Row1        0        1        2        3        4        5
# Row2        6        7        8        9       10       11
# Row3       12       13       14       15       16       17
# Row4       18       19       20       21       22       23
# Row5       24       25       26       27       28       29

# %%
df.iloc[3:5, :]
# Out:
#       Column1  Column2  Column3  Column4  Column5  Column6
# Row4       18       19       20       21       22       23
# Row5       24       25       26       27       28       29

# %%
df = pd.read_csv("csv_data.csv") #reads csv file
df
# Out:
#   First Name Last Name                 School                         College  \
# 0       Arin    Sharma  St. Vishna RRN School         Mangalayatan University
# 1     Advik      Verma     Kendriya Vidyalaya  National Law University, Delhi
# 2     Vishal     Verma     Kendriya Vidyalaya        National Defence Academy
# 3      Vikas     Singh     Kendriya Vidyalaya                   AIIMS (Delhi)
# 4  Vaishnavi     Singh     Kendriya Vidyalaya                 NIT Kurukshetra
# 5    Rishita     Bhatt     Kendriya Vidyalaya                     IIT Roorkee
#
#   Grade (Intermediate)          State
# 0                  65%  Uttar Pradesh
# 1                  68%    Uttarakhand
# 2                  86%    Uttarakhand
# 3                  88%          Bihar
# 4                  84%        Haryana
# 5               99.20%        Gujarat

# %%
data = pd.read_json("json_data.json") #reads json data
data.head() #lists first 5 data
# Out:
#    id                         title                      slug  \
# 0   1           Guitar Fundamentals       guitar-fundamentals
# 1   2           Advanced Jazz Piano       advanced-jazz-piano
# 2   3         Drums: Rhythm Mastery      drums-rhythm-mastery
# 3   4  Vocal Training for Beginners  vocal-training-beginners
# 4   5   Music Production in Ableton  music-production-ableton
#
#                                          description   price      instructor  \
# 0  Learn the basics of playing guitar with our co...   99.99        John Doe
# 1  Explore complex chords, improvisation, and jaz...  149.99      Sarah Chen
# 2  Techniques for various drumming styles includi...  119.50    Mike Johnson
# 3  Improve pitch, breathing control, and vocal ra...   89.00      Aisha Khan
# 4  From recording to mixing, master the digital a...  199.99  Alex Rodriguez
#
#    isFeatured                                              image
# 0        True  https://images.unsplash.com/photo-152520154086...
# 1       False  https://images.unsplash.com/photo-1549419615-5...
# 2        True  https://images.unsplash.com/photo-1558296245-7...
# 3       False  https://images.unsplash.com/photo-157777748450...
# 4        True  https://images.unsplash.com/photo-151860013917...

# %%
data = pd.read_excel("excel_data.xlsx") #reads excel data
data.tail() #reads last 5 data
# Out:
#   First Name Last Name              School                         College  \
# 1     Advik      Verma  Kendriya Vidyalaya  National Law University, Delhi
# 2     Vishal     Verma  Kendriya Vidyalaya        National Defence Academy
# 3      Vikas     Singh  Kendriya Vidyalaya                   AIIMS (Delhi)
# 4  Vaishnavi     Singh  Kendriya Vidyalaya                 NIT Kurukshetra
# 5    Rishita     Bhatt  Kendriya Vidyalaya                     IIT Roorkee
#
#    Grade (Intermediate)        State
# 1                 0.680  Uttarakhand
# 2                 0.860  Uttarakhand
# 3                 0.880        Bihar
# 4                 0.840      Haryana
# 5                 0.992      Gujarat

# %%
#Creating Data
data = {
    "Name": ["Arin", "Rishita", "Advik"],
    "Age": [21, 21, 20],
    "State": ["Uttar Pradesh", "Gujarat", "Uttarakhand"]
}

# %%
df = pd.DataFrame(data) #creating data into dataframe
df
# Out:
#       Name  Age          State
# 0     Arin   21  Uttar Pradesh
# 1  Rishita   21        Gujarat
# 2    Advik   20    Uttarakhand

# %%
df.to_csv("data.csv", index=False) #creates data into csv file

# %%
df.to_excel("data.xlsx", index=False)  #creates data into excel file

# %%
df.to_json("data.json", index=False)  #creates data into json file
df
# Out:
#         Name  Grade           State  Gender  Salary
# 0       Arin     65   Uttar Pradesh    Male   60000
# 1    Rishita     99         Gujarat  Female  950000
# 2  Vaishnavi     84         Haryana  Female   40000
# 3      Advik     68     Uttarakhand    Male   20000
# 4     Vishal     86     Uttarakhand    Male   10000
# 5    Radhika     88  Madhya Pradesh  Female   65000

# %%
df = pd.read_csv("csv_data.csv") #reads csv file
df
# Out:
#   First Name Last Name                 School                         College  \
# 0       Arin    Sharma  St. Vishna RRN School         Mangalayatan University
# 1     Advik      Verma     Kendriya Vidyalaya  National Law University, Delhi
# 2     Vishal     Verma     Kendriya Vidyalaya        National Defence Academy
# 3      Vikas     Singh     Kendriya Vidyalaya                   AIIMS (Delhi)
# 4  Vaishnavi     Singh     Kendriya Vidyalaya                 NIT Kurukshetra
# 5    Rishita     Bhatt     Kendriya Vidyalaya                     IIT Roorkee
#
#   Grade (Intermediate)          State
# 0                  65%  Uttar Pradesh
# 1                  68%    Uttarakhand
# 2                  86%    Uttarakhand
# 3                  88%          Bihar
# 4                  84%        Haryana
# 5               99.20%        Gujarat

# %%
df.head(1) #return first data
# Out:
#   First Name Last Name                 School                  College  \
# 0       Arin    Sharma  St. Vishna RRN School  Mangalayatan University
#
#   Grade (Intermediate)          State
# 0                  65%  Uttar Pradesh

# %%
df.tail(1) #return last data
# Out:
#   First Name Last Name              School      College Grade (Intermediate)  \
# 5    Rishita     Bhatt  Kendriya Vidyalaya  IIT Roorkee               99.20%
#
#      State
# 5  Gujarat

# %%
df.info() #returns data summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   First Name            6 non-null      object
#  1   Last Name             6 non-null      object
#  2   School                6 non-null      object
#  3   College               6 non-null      object
#  4   Grade (Intermediate)  6 non-null      object
#  5   State                 6 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
df.describe()
# Out:
#        First Name Last Name              School                  College  \
# count           6         6                   6                        6
# unique          6         4                   2                        6
# top          Arin     Verma  Kendriya Vidyalaya  Mangalayatan University
# freq            1         2                   5                        1
#
#        Grade (Intermediate)        State
# count                     6            6
# unique                    6            5
# top                     65%  Uttarakhand
# freq                      1            2

# %%
#Creating Data
data = {
    "Name": ["Arin", "Rishita", "Vaishnavi", "Advik", "Vishal", "Radhika"],
    "Grade": [65, 99, 84, 68, 86, 88],
    "State": ["Uttar Pradesh", "Gujarat", "Haryana","Uttarakhand", "Uttarakhand", "Madhya Pradesh"],
    "Gender": ["Male", "Female", "Female", "Male","Male", "Female"],
    "Salary": [60000, 950000, 40000, 20000, 10000, 65000]
}
df = pd.DataFrame(data)
df
# Out:
#         Name  Grade           State  Gender  Salary
# 0       Arin     65   Uttar Pradesh    Male   60000
# 1    Rishita     99         Gujarat  Female  950000
# 2  Vaishnavi     84         Haryana  Female   40000
# 3      Advik     68     Uttarakhand    Male   20000
# 4     Vishal     86     Uttarakhand    Male   10000
# 5    Radhika     88  Madhya Pradesh  Female   65000

# %%
df.describe() # generate descriptive statistics of a dataFrame
# Out:
#            Grade         Salary
# count   6.000000       6.000000
# mean   81.666667  190833.333333
# std    12.878923  372537.470151
# min    65.000000   10000.000000
# 25%    72.000000   25000.000000
# 50%    85.000000   50000.000000
# 75%    87.500000   63750.000000
# max    99.000000  950000.000000

# %% [markdown]
# #### Knowing column and shape of dataset

# %%
df.shape #returns shape
# Out:
# (6, 5)

# %%
df.columns #returns columns
# Out:
# Index(['Name', 'Grade', 'State', 'Gender', 'Salary'], dtype='object')

# %% [markdown]
# #### Filtering based on condition

# %%
salary = df[df["Salary"]> 50000]
salary
# Out:
#       Name  Grade           State  Gender  Salary
# 0     Arin     65   Uttar Pradesh    Male   60000
# 1  Rishita     99         Gujarat  Female  950000
# 5  Radhika     88  Madhya Pradesh  Female   65000

# %%
lower_salary = df[(df["Salary"] > 10000) & (df["Salary"] < 50000)]
lower_salary
# Out:
#         Name  Grade        State  Gender  Salary
# 2  Vaishnavi     84      Haryana  Female   40000
# 3      Advik     68  Uttarakhand    Male   20000

# %%
df["Name"] #returns single column
# Out:
# 0         Arin
# 1      Rishita
# 2    Vaishnavi
# 3        Advik
# 4       Vishal
# 5      Radhika
# Name: Name, dtype: object

# %%
df[["Name", "Salary"]] #returns multiple columns
# Out:
#         Name  Salary
# 0       Arin   60000
# 1    Rishita  950000
# 2  Vaishnavi   40000
# 3      Advik   20000
# 4     Vishal   10000
# 5    Radhika   65000

# %%
higher_rankers = df[(df["Grade"] > 85) & (df["Grade"] < 90)]
higher_rankers
# Out:
#       Name  Grade           State  Gender  Salary
# 4   Vishal     86     Uttarakhand    Male   10000
# 5  Radhika     88  Madhya Pradesh  Female   65000

# %%
passed = df[(df["Grade"] > 50) & (df["Grade"] < 70)]
passed
# Out:
#     Name  Grade          State Gender  Salary
# 0   Arin     65  Uttar Pradesh   Male   60000
# 3  Advik     68    Uttarakhand   Male   20000

# %%
df
# Out:
#         Name  Grade           State  Gender  Salary
# 0       Arin     65   Uttar Pradesh    Male   60000
# 1    Rishita     99         Gujarat  Female  950000
# 2  Vaishnavi     84         Haryana  Female   40000
# 3      Advik     68     Uttarakhand    Male   20000
# 4     Vishal     86     Uttarakhand    Male   10000
# 5    Radhika     88  Madhya Pradesh  Female   65000

# %%
successfull = df[(df["Grade"] > 70) | (df["Salary"] > 15000)]
successfull
# Out:
#         Name  Grade           State  Gender  Salary
# 0       Arin     65   Uttar Pradesh    Male   60000
# 1    Rishita     99         Gujarat  Female  950000
# 2  Vaishnavi     84         Haryana  Female   40000
# 3      Advik     68     Uttarakhand    Male   20000
# 4     Vishal     86     Uttarakhand    Male   10000
# 5    Radhika     88  Madhya Pradesh  Female   65000

# %%
url = 'https://www.fdic.gov/bank/individual/failed/banklist.html'
dfs = pd.read_html(url)

# %%
dfs[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# 12                                 Ericson State Bank             Ericson
# 13                   City National Bank of New Jersey              Newark
# 14                                      Resolute Bank              Maumee
# 15                              Louisa Community Bank              Louisa
# 16                               The Enloe State Bank              Cooper
# 17                Washington Federal Bank for Savings             Chicago
# 18    The Farmers and Merchants State Bank of Argonia             Argonia
# 19                                Fayette County Bank          Saint Elmo
# 20  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 21                                     First NBC Bank         New Orleans
# 22                                      Proficio Bank  Cottonwood Heights
# 23                      Seaway Bank and Trust Company             Chicago
# 24                             Harvest Community Bank          Pennsville
#
#             State   Cert                Acquiring Institution  \
# 0           Texas   5520            Coleman County State Bank
# 1        Illinois  28611                      Millennium Bank
# 2        Oklahoma   4134               First Bank & Trust Co.
# 3    Pennsylvania  27332    Fulton Bank, National Association
# 4            Iowa   8758            Iowa Trust & Savings Bank
# 5          Kansas  25851               Dream First Bank, N.A.
# 6      California  59017            JPMorgan Chase Bank, N.A.
# 7        New York  57053                  Flagstar Bank, N.A.
# 8      California  24735  First Citizens Bank & Trust Company
# 9          Kansas  15426                          Equity Bank
# 10        Florida  16748            United Fidelity Bank, fsb
# 11  West Virginia  14361                       MVB Bank, Inc.
# 12       Nebraska  18265           Farmers and Merchants Bank
# 13     New Jersey  21111                      Industrial Bank
# 14           Ohio  58317                   Buckeye State Bank
# 15       Kentucky  58112    Kentucky Farmers Bank Corporation
# 16          Texas  10716                   Legend Bank, N. A.
# 17       Illinois  30570                   Royal Savings Bank
# 18         Kansas  17719                          Conway Bank
# 19       Illinois   1802            United Fidelity Bank, fsb
# 20      Wisconsin  30003  First-Citizens Bank & Trust Company
# 21      Louisiana  58302                         Whitney Bank
# 22           Utah  35495                    Cache Valley Bank
# 23       Illinois  19328                  State Bank of Texas
# 24     New Jersey  34951  First-Citizens Bank & Trust Company
#
#          Closing Date  Fund  Sort ascending
# 0       June 27, 2025                 10549
# 1    January 17, 2025                 10548
# 2    October 18, 2024                 10547
# 3      April 26, 2024                 10546
# 4    November 3, 2023                 10545
# 5       July 28, 2023                 10544
# 6         May 1, 2023                 10543
# 7      March 12, 2023                 10540
# 8      March 10, 2023                 10539
# 9    October 23, 2020                 10538
# 10   October 16, 2020                 10537
# 11      April 3, 2020                 10536
# 12  February 14, 2020                 10535
# 13   November 1, 2019                 10534
# 14   October 25, 2019                 10533
# 15   October 25, 2019                 10532
# 16       May 31, 2019                 10531
# 17  December 15, 2017                 10530
# 18   October 13, 2017                 10529
# 19       May 26, 2017                 10528
# 20        May 5, 2017                 10527
# 21     April 28, 2017                 10526
# 22      March 3, 2017                 10525
# 23   January 27, 2017                 10524
# 24   January 13, 2017                 10523

# %%
country_code = 'https://en.wikipedia.org/wiki/Mobile_country_code'
dfs = pd.read_html(country_code, match='Mobile Network Codes', header=0)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 country_code = 'https://en.wikipedia.org/wiki/Mobile_country_code'
# ----> 2 dfs = pd.read_html(country_code, match='Mobile Network Codes', header=0)
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     972 p = parser(
#     973     io,
#     974     compiled_match,
#    (...)    979     storage_options,
#     980 )
#     982 try:
# --> 983     tables = p.parse_tables()
#     984 except ValueError as caught:
#     985     # if `io` is an io-like object, check if it's seekable
#     986     # and try to rewind it before trying the next parser
#     987     if hasattr(io, "seekable") and io.seekable():
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\html.py:249, in _HtmlFrameParser.parse_tables(self)
#     241 def parse_tables(self):
#     242     """
#     243     Parse and return all tables from the DOM.
#     244
#    (...)    247     list of parsed (header, body, footer) tuples from tables.
#     248     """
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\html.py:806, in _LxmlFrameParser._build_doc(self)
#     804             pass
#     805     else:
# --> 806         raise e
#     807 else:
#     808     if not hasattr(r, "text_content"):
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\html.py:785, in _LxmlFrameParser._build_doc(self)
#     783 try:
#     784     if is_url(self.io):
# --> 785         with get_handle(
#     786             self.io, "r", storage_options=self.storage_options
#     787         ) as f:
#     788             r = parse(f.handle, parser=parser)
#     789     else:
#     790         # try to parse the input in the simplest way
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:187, in urlopen(url, data, timeout, context)
#     185 else:
#     186     opener = _opener
# --> 187 return opener.open(url, data, timeout)
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:493, in OpenerDirector.open(self, fullurl, data, timeout)
#     491 for processor in self.process_response.get(protocol, []):
#     492     meth = getattr(processor, meth_name)
# --> 493     response = meth(req, response)
#     495 return response
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:602, in HTTPErrorProcessor.http_response(self, request, response)
#     599 # According to RFC 2616, "2xx" code indicates that the client's
#     600 # request was successfully received, understood, and accepted.
#     601 if not (200 <= code < 300):
# --> 602     response = self.parent.error(
#     603         'http', request, response, code, msg, hdrs)
#     605 return response
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:531, in OpenerDirector.error(self, proto, *args)
#     529 if http_err:
#     530     args = (dict, 'default', 'http_error_default') + orig_args
# --> 531     return self._call_chain(*args)
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:464, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     462 for handler in handlers:
#     463     func = getattr(handler, meth_name)
# --> 464     result = func(*args)
#     465     if result is not None:
#     466         return result
#
# File c:\Users\Arin_Sharma\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:611, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     610 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 611     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
