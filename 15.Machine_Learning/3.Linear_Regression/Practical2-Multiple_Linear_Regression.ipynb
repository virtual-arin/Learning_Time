# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from sklearn.datasets import make_regression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
x,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':x[:,0], 'feature2':x[:,1], 'target': 'y'})

# %%
df.head()
# Out:
#    feature1  feature2 target
# 0 -3.438761 -0.407103      y
# 1  0.303753 -0.907604      y
# 2  1.846587 -1.884505      y
# 3  0.621872  0.364487      y
# 4 -1.696493  0.457093      y

# %%
df.shape
# Out:
# (100, 3)

# %%
fig = px.scatter_3d(df, x="feature1", y="feature1", z="target") 
fig.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

# %%
len(x_test)
# Out:
# 20

# %%
from sklearn.linear_model import LinearRegression
linear_regression = LinearRegression()
linear_regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = linear_regression.predict(x_test)

# %%
y_prediction
# Out:
# array([-42.3194749 ,  27.33592754,  45.95273926,  39.13454229,
#        -26.27784852,  43.23157439,   6.68398188, -29.01341473,
#        -14.02580094,  -7.7312823 ,  21.89076497,   2.99578278,
#        -49.06920599, -94.92889932,  24.59522343,   2.46841031,
#         -8.83902362, -13.94866885,  33.19667342,   8.00449576])

# %%
y_test
# Out:
# array([  44.26033763,   97.52671277,  -18.79918618,   42.84172958,
#           5.75327498,  -47.02897914,  155.7657595 ,  -28.35107679,
#         -71.67009314,  -42.86283959,  -21.4255747 ,    4.03618144,
#         -91.61660628,  -34.50680945,   -9.47578882,  -67.87203236,
#          51.94972345, -121.51041237,   72.92741168,  -88.99957175])

# %%
print('MAE:', mean_absolute_error(y_test, y_prediction))
# Out:
# MAE: 57.34321661780687

# %%
print('MSE:', mean_squared_error(y_test, y_prediction))
# Out:
# MSE: 4614.273119758808

# %%
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_prediction)))
# Out:
# RMSE: 67.92844116979875

# %%
print('R2-Score:', r2_score(y_test, y_prediction))
# Out:
# R2-Score: -0.0033799216145733446
